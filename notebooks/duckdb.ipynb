# %%
# %pip install duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 43.4 MB/s eta 0:00:00:00:01
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb

con = duckdb.connect()

con.sql("""
SELECT *
FROM '../data/atlantis.csv'
""")
# Out:
# ┌───────┬────────────┐
# │ year  │ population │
# │ int64 │   int64    │
# ├───────┼────────────┤
# │  2000 │      12400 │
# │  2001 │      12800 │
# │  2002 │      13800 │
# │  2003 │      13600 │
# │  2004 │      14200 │
# │  2005 │      15600 │
# │  2006 │      17600 │
# │  2007 │      19200 │
# │  2008 │      20300 │
# │  2009 │      20800 │
# │  2010 │      21200 │
# │  2011 │      22400 │
# │  2012 │      23400 │
# │  2013 │      24500 │
# │  2014 │      25800 │
# │  2015 │      26100 │
# │  2016 │      28300 │
# │  2017 │      29600 │
# │  2018 │      32100 │
# │  2019 │      32500 │
# │  2020 │      33200 │
# │  2021 │      33800 │
# └───────┴────────────┘
#   22 rows  2 columns
